# %% [markdown]
# #### Spotipy is a python library for Spotify Web API. With Spotipy you get full access to all of the music data provided by the Spotify platform.

# %%
pip install spotipy
# Out:
# ...
#      ------------------------------------ 250.3/250.3 KB 415.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Users\dsk_f\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# #### We need Client ID and Client Secret id to access data

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# Here we provide client_id and client_secret
client_credentials_manager = SpotifyClientCredentials(client_id='5464974277bf43049dc949c5899e143c', client_secret='e0ba181e852d4f6c931600db8ee31f52')

# %%
# We create spotify object so we can use methods and acess data
sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)

# %%
# assign url of TOP 50 Global song playlist to a variable 
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'

# %%
# We need the playlist id so we extract it using split
playlist_URI= playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-10-18T09:31:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2023-10-18T09:31:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-10-18T09:31:29Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
data['items'][0]['track']['artists'][0]['name']                     # Artists
# Out:
# 'Bad Bunny'

# %%
data['items'][0]['track']['album']['name']                         # Album
# Out:
# 'nadie sabe lo que va a pasar mañana'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4FftCsAcXXD1nFO9RFUNFO'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-10-13'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 22

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4FftCsAcXXD1nFO9RFUNFO'

# %%
data['items'][0]['track']['name']                                  # Track
# Out:
# 'MONACO'

# %%
# looping through all album
data['items'][0]['track']['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#    'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#    'id': '4q3ewBCX7sLwd24euuV69X',
#    'name': 'Bad Bunny',
#    'type': 'artist',
#    'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'name': 'nadie sabe lo que va a pasar mañana',
#   'release_date': '2023-10-13',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/4FftCsAcXXD1nFO9RFUNFO'},
#  {'album_id': '53985D8g3JcGBoULSOYYKX',
#   'name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'name': 'Scarlet',
#   'release_date': '2023-09-20',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#  {'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'name': 'Si No Estás',
#   'release_date': '2022-09-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#  {'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'name': 'nadie sabe lo que va a pasar mañana',
#   'release_date': '2023-10-13',
#   'total_tracks': 22,
# ...

# %%
# Artists

data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#   'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#   'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'name': 'Latto',
#   'type': 'artist',
#   'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}]

# %%
artists_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artists_dict={'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artists_list.append(artists_dict)
print(artists_list)
# Out:
# [{'artist_id': '4q3ewBCX7sLwd24euuV69X', 'artist_name': 'Bad Bunny', 'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'}, {'artist_id': '6HaGTQPmzraVmaVxvz6EUc', 'artist_name': 'Jung Kook', 'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'}, {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ', 'artist_name': 'Latto', 'external_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'}, {'artist_id': '5cj0lLjcoR7YOSnhnX0Po5', 'artist_name': 'Doja Cat', 'external_url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'}, {'artist_id': '0jbo7KFNMiIkfBR6ih0yhm', 'artist_name': 'iñigo quintero', 'external_url': 'https://api.spotify.com/v1/artists/0jbo7KFNMiIkfBR6ih0yhm'}, {'artist_id': '4q3ewBCX7sLwd24euuV69X', 'artist_name': 'Bad Bunny', 'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'}, {'artist_id': '2LRoIwlKmHjgvigdNGBHNo', 'artist_name': 'Feid', 'external_url': 'https://api.spotify.com/v1/artists/2LRoIw
# ...

# %%
for row in data['items']:
    row['track']['name']

# %%
# Track
data['items'][0]['track']['name']
# Out:
# 'MONACO'

# %%
data['items'][1]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#   'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#   'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'name': 'Latto',
#   'type': 'artist',
#   'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}]

# %%
data['items']
# Out:
# [{'added_at': '2023-10-18T09:31:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '4MjDJD8cW7iVeWInc2Bdyj',
#   'song_name': 'MONACO',
#   'duration_ms': 267194,
#   'url': 'https://open.spotify.com/track/4MjDJD8cW7iVeWInc2Bdyj',
#   'popularity': 91,
#   'song_added': '2023-10-18T09:31:29Z',
#   'album_id': '4FftCsAcXXD1nFO9RFUNFO',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#   'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'duration_ms': 184400,
#   'url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#   'popularity': 98,
#   'song_added': '2023-10-18T09:31:29Z',
#   'album_id': '53985D8g3JcGBoULSOYYKX',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '56y1jOTK0XSvJzVv9vHQBK',
#   'song_name': 'Paint The Town Red',
#   'duration_ms': 230480,
#   'url': 'https://open.spotify.com/track/56y1jOTK0XSvJzVv9vHQBK',
#   'popularity': 87,
#   'song_added': '2023-10-18T09:31:29Z',
#   'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
# ...

# %% [markdown]
# ## Convert all this to DataFrame

# %%
# Album

album_df= pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                 name release_date  \
# 0  4FftCsAcXXD1nFO9RFUNFO  nadie sabe lo que va a pasar mañana   2023-10-13
# 1  53985D8g3JcGBoULSOYYKX                  Seven (feat. Latto)   2023-07-14
# 2  1bBez9PNvkJPW08bU7NYta                              Scarlet   2023-09-20
# 3  66k6EGkPtYoN44anGIsEPW                          Si No Estás   2022-09-23
# 5  3UOV8XvCwMKaATRNXrYCjN                               greedy   2023-09-15
#
#    total_tracks                                                url
# 0            22  https://open.spotify.com/album/4FftCsAcXXD1nFO...
# 1             3  https://open.spotify.com/album/53985D8g3JcGBoU...
# 2            15  https://open.spotify.com/album/1bBez9PNvkJPW08...
# 3             1  https://open.spotify.com/album/66k6EGkPtYoN44a...
# 5             1  https://open.spotify.com/album/3UOV8XvCwMKaATR...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\dsk_f\AppData\Local\Temp\ipykernel_7812\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 46
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      35 non-null     object
#  1   name          35 non-null     object
#  2   release_date  35 non-null     datetime64[ns]
#  3   total_tracks  35 non-null     int64
#  4   url           35 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
# Artist

artist_df= pd.DataFrame.from_dict(artists_list)

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 1  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ           Latto
# 3  5cj0lLjcoR7YOSnhnX0Po5        Doja Cat
# 4  0jbo7KFNMiIkfBR6ih0yhm  iñigo quintero
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 3  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 4  https://api.spotify.com/v1/artists/0jbo7KFNMiI...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.shape
# Out:
# (49, 3)

# %%
# Song

song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                            song_name  duration_ms  \
# 0  4MjDJD8cW7iVeWInc2Bdyj                               MONACO       267194
# 1  7x9aauaA9cu6tyfpHnqDLo  Seven (feat. Latto) (Explicit Ver.)       184400
# 2  56y1jOTK0XSvJzVv9vHQBK                   Paint The Town Red       230480
# 3  2HafqoJbgXdtjwCOvNEF14                          Si No Estás       184061
# 4  7iQXYTyuG13aoeHxGG28Nh                          PERRO NEGRO       162767
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/4MjDJD8cW7iVeWI...          91
# 1  https://open.spotify.com/track/7x9aauaA9cu6tyf...          98
# 2  https://open.spotify.com/track/56y1jOTK0XSvJzV...          87
# 3  https://open.spotify.com/track/2HafqoJbgXdtjwC...          95
# 4  https://open.spotify.com/track/7iQXYTyuG13aoeH...          89
#
#                  song_added                album_id               artist_id
# ...

# %%
song_df['song_added']= pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB

# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.4

# %%
from datetime import datetime

# %%
str(datetime.now())
# Out:
# '2023-10-19 00:14:27.502779'

# %%
import json
from datetime import datetime
import os                                      # for accessing enviroment variable
import spotipy
import boto3                                   # for dumping entire extracted dat to s3
from spotipy.oauth2 import SpotifyClientCredentials

def lambda_handler(event, context):
    
    client_id = os.environ.get('client_id')
    client_secret = os.environ.get('client_secret')
    
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)
    
    playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'
    playlist_URI = playlist_link.split("/")[-1].split('?')[0]
    playlist_URI= playlist_link.split('/')[-1]
    spotify_data = sp.playlist_tracks(playlist_URI)
    
    client = boto3.client('s3')
    filename = 'spotify_raw_'+str(datetime.now())+'.json'
    client.put_object(Bucket='spotify-etl-project-ankita',
                      Key='raw_data/to_processed/'+filename,
                      Body=json.dumps(spotify_data))
